# %% [markdown]
# # Satellite Imagery Classification using Attention-based Deep MIL

# %% [markdown]
# Date: 27/04/2025
#
# Aristotle University of Thessaloniki
#
# MSc in Artificial Intelligence

# %% [markdown]
# ## Import Libraries

# %%
# !pip install pydot graphviz

# %%
import numpy as np
import keras
from keras import layers, ops
from tqdm import tqdm
from matplotlib import pyplot as plt
import gdown
import requests
import os
import yaml
import random
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, precision_recall_curve, auc
from scipy.stats import chi2_contingency
import tensorflow as tf
from tensorflow.keras.applications.xception import Xception
# Set the seed for random function of python
random.seed(1)
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import pandas as pd

# %% [markdown]
# ## Unzip Bags dataset

# %% [markdown]
# First of all, we need to collect the dataset containing the night-time images from the VIIRS satellite images. In this experiment the bagsAugmented variant will be used, which contains the images augmented with various techniques such as random rotation, flip, etc.

# %%
# unzip fetched dataset (need to mount Drive)
# !unzip -q /content/drive/MyDrive/VIIRS/bagsAugmented.zip -d /content/

# %% [markdown]
# ## Collect GDB statistics

# %% [markdown]
# The second step, is about collecting the labels that will be used in this experiment. The Gross domestic product (GDP) will be used as found in Eurostat.
# The GDP score for each country was collected per year, and afterwards generated a binary version, using as threshold <70 for countries with low GDP, and >=70 for countries with high GDP score.

# %%
# download y labels yaml file from github
url = "https://raw.githubusercontent.com/pleleGit/SatSenseAI/main/statistics/gdp.yaml"
response = requests.get(url)

with open("gdb.yaml", "wb") as f:
    f.write(response.content)

with open("gdb.yaml", "r") as f:
    gdb = yaml.safe_load(f)
gdb = gdb["gdp_per_capita_index"]

# collect all values of gdb and create a box plot
plt.figure(figsize=(12, 10))
scores = []
for key in gdb.keys():
    scores.append(gdb[key])
scores = np.array(scores).flatten()
plt.boxplot(scores)
plt.yticks(range(20, 160, 10))
plt.grid()
plt.title("Distribution of GDP per Capita Index") # Add title
plt.ylabel("GDP per Capita Index") # Add y-axis label
plt.xticks([1], ['Gross Domestic Product (GDP)']) # Add x-axis label

# Add a horizontal line at y=70 denoting the threshold
plt.hlines(y=70, xmin=0.925, xmax=1.075, color='b', linestyle='--', label='Threshold (GDP < 70: Low, GDP >= 70: High)')
plt.legend() # Add a legend to show the label for the threshold line

plt.show()

# %%
# download y labels yaml file from github
url = "https://raw.githubusercontent.com/pleleGit/SatSenseAI/main/statistics/gdbBinary.yaml"
response = requests.get(url)

with open("gdbBinary.yaml", "wb") as f:
    f.write(response.content)

# %% [markdown]
# ## Create & Import Bags

# %% [markdown]
# This section focuses on loading and organizing the satellite imagery dataset for training an **Attention-based Deep Multiple Instance Learning (MIL)** model. It starts by importing the GDP labels from a YAML file, which will be used as the **target variable**. Then, it iterates through the dataset, which is structured by country and year. For each country and year, it randomly selects a fixed number of image instances (50) to form a "bag". These bags are then assigned to training, validation, or test sets based on the country and year. The bags and their corresponding GDP labels are stored in separate lists for each dataset split (train, validation, test). Finally, it prints statistics about the created datasets, including the number of bags, instances per bag, instance shape, and label shape. This organized data is then ready to be used for training the MIL model in subsequent steps.

# %%
# load gdbBinary.yaml
with open("gdbBinary.yaml", "r") as f:
    gdbBinary = yaml.safe_load(f)

# %%
gdb = gdbBinary["gdp_per_capita_index"]

# %%
# load custom Bags dataset for training with Keras
train_bags = []
val_bags = []
test_bags = []
dataset_path = "/content/bagsAugmented"
instances_count = 40
train_bags_labels = []
val_bags_labels = []
test_bags_labels = []
countries = sorted(os.listdir(dataset_path))
years = sorted(os.listdir(os.path.join(dataset_path, countries[0])))
print(f"Countries: {countries}")
print(f"Bags per year: {years}")
train_countries = random.sample(countries, 12)
for i, country in enumerate(countries):
    val_year = random.sample(years, 2)
    for year_bag in years:
        bag = []
        # Get the list of files
        all_files = os.listdir(os.path.join(dataset_path, country, year_bag))
        # Pick 30 random files without replacement
        selected_files = random.sample(all_files, instances_count)
        for img_path in selected_files:
            # Loads each image into PIL format
            img = keras.preprocessing.image.load_img(os.path.join(dataset_path, country, year_bag, img_path),
                                                    target_size=(300, 225),
                                                    color_mode="grayscale")
            # Converts a PIL Image instance to a NumPy array
            img_array = keras.preprocessing.image.img_to_array(img)
            img_array = img_array / 255.0  # standardize image to [0, 1]
            bag.append(img_array)
            if len(bag) == instances_count:
                break
        # collect the corresponding gdp per capita index
        id = int(year_bag[1:]) - 14
        if country in train_countries:
            if year_bag in val_year:
                val_bags.append(bag)
                val_bags_labels.append([gdb[country][id]])
            else:
                train_bags.append(bag)
                train_bags_labels.append([gdb[country][id]])
        else:
            test_bags.append(bag)
            test_bags_labels.append([gdb[country][id]])
train_bags = np.squeeze(np.swapaxes(np.array(train_bags), 0, 1))
train_bags_labels = np.array(train_bags_labels)
val_bags = np.squeeze(np.swapaxes(np.array(val_bags), 0, 1))
val_bags_labels = np.array(val_bags_labels)
test_bags = np.squeeze(np.swapaxes(np.array(test_bags), 0, 1))
test_bags_labels = np.array(test_bags_labels)
# Out:
# Countries: ['Albania', 'Austria', 'Belgium', 'Bosnia', 'Bulgaria', 'England', 'FYROM', 'France', 'Germany', 'Greece', 'Hungary', 'Italy', 'Montenegro', 'Netherlands', 'Poland', 'Portugal', 'Romania', 'Serbia', 'Spain']
# Bags per year: ['b14', 'b15', 'b16', 'b17', 'b18', 'b19', 'b20', 'b21', 'b22', 'b23']

# %%
print("~~~~~~~~~~~ Stats for training set: ~~~~~~~~~~~")
print(f"Bags Shape: {train_bags.shape}")
print(f"Number of Bags: {train_bags.shape[1]}")
print(f"Number of Instances per Bag: {train_bags.shape[0]}")
print(f"Shape of each Instance: {train_bags.shape[2:]}")
print(f"Shape of Labels: {train_bags_labels.shape}")
print("~~~~~~~~~~~ Stats for validation set: ~~~~~~~~~~~")
print(f"Bags Shape: {val_bags.shape}")
print(f"Number of Bags: {val_bags.shape[1]}")
print(f"Number of Instances per Bag: {val_bags.shape[0]}")
print(f"Shape of each Instance: {val_bags.shape[2:]}")
print(f"Shape of Labels: {val_bags_labels.shape}")
print("~~~~~~~~~~~ Stats for test set: ~~~~~~~~~~~")
print(f"Bags Shape: {test_bags.shape}")
print(f"Number of Bags: {test_bags.shape[1]}")
print(f"Number of Instances per Bag: {test_bags.shape[0]}")
print(f"Shape of each Instance: {test_bags.shape[2:]}")
print(f"Shape of Labels: {test_bags_labels.shape}")
train_bags = list(train_bags)
val_bags = list(val_bags)
test_bags = list(test_bags)
# Out:
# ~~~~~~~~~~~ Stats for training set: ~~~~~~~~~~~
# Bags Shape: (40, 96, 300, 225)
# Number of Bags: 96
# Number of Instances per Bag: 40
# Shape of each Instance: (300, 225)
# Shape of Labels: (96, 1)
# ~~~~~~~~~~~ Stats for validation set: ~~~~~~~~~~~
# Bags Shape: (40, 24, 300, 225)
# Number of Bags: 24
# Number of Instances per Bag: 40
# Shape of each Instance: (300, 225)
# Shape of Labels: (24, 1)
# ~~~~~~~~~~~ Stats for test set: ~~~~~~~~~~~
# Bags Shape: (40, 70, 300, 225)
# Number of Bags: 70
# Number of Instances per Bag: 40
# Shape of each Instance: (300, 225)
# Shape of Labels: (70, 1)

# %%
print(f"Positive / Negative Bags in train set: {np.sum(train_bags_labels)} / {train_bags_labels.shape[0] - np.sum(train_bags_labels)}")
print(f"Positive / Negative Bags in validation set: {np.sum(val_bags_labels)} / {val_bags_labels.shape[0] - np.sum(val_bags_labels)}")
print(f"Positive / Negative Bags in test set: {np.sum(test_bags_labels)} / {test_bags_labels.shape[0] - np.sum(test_bags_labels)}")
# Out:
# Positive / Negative Bags in train set: 61 / 35
# Positive / Negative Bags in validation set: 14 / 10
# Positive / Negative Bags in test set: 35 / 35

# %% [markdown]
# From the upper selection, it is clear that the classes in the train and test set are slightly imbalanced, which will be handled during the next training sections.

# %% [markdown]
# ## Prepare the MIL Attention layer

# %% [markdown]
# In this section a custom Keras layer called MILAttentionLayer is defined, which is crucial for implementing the attention mechanism in the Multiple Instance Learning (MIL) model. This layer is designed to **learn and assign attention weights to individual instances within a bag**, allowing the model to focus on the most relevant instances for prediction. The MILAttentionLayer incorporates a gated mechanism that enhances the learning of non-linear relationships between instances and their corresponding bag labels. By computing attention scores and applying softmax normalization, the layer ensures that **the attention weights sum up to 1**, effectively highlighting the importance of each instance in the bag. This attention mechanism is a key component of the MIL model, enabling it to effectively handle bags of instances and make accurate predictions based on the **most informative instances within each bag**.

# %%
class MILAttentionLayer(layers.Layer):
    def __init__(self, weight_dim, kernel_init="glorot_uniform", kernel_reg="None", use_gated=False, **kwargs):
        super().__init__(**kwargs)
        self.weight_dim = weight_dim  # dimension of the weight matrix
        self.use_gated = use_gated  # to enable/disable gated mechanism
        self.kernel_init = keras.initializers.get(kernel_init)
        self.kernel_reg = keras.regularizers.get(kernel_reg)

        self.v_init = self.kernel_init
        self.w_init = self.kernel_init
        self.u_init = self.kernel_init

        self.v_reg = self.kernel_reg
        self.w_reg = self.kernel_reg
        self.u_reg = self.kernel_reg

    def build(self, input_shape):
        # Input shape.
        # List of 2D tensors with shape: (batch_size, input_dim).
        input_dim = input_shape[0][1]
        self.v_weight_params = self.add_weight(
            shape=(input_dim, self.weight_dim),
            initializer=self.v_init,
            name="v",
            regularizer=self.v_reg,
            trainable=True,
        )
        self.w_weight_params = self.add_weight(
            shape=(self.weight_dim, 1),
            initializer=self.w_init,
            name="w",
            regularizer=self.w_reg,
            trainable=True,
        )
        if self.use_gated:
            self.u_weight_params = self.add_weight(
                shape=(input_dim, self.weight_dim),
                initializer=self.u_init,
                name="u",
                regularizer=self.u_reg,
                trainable=True,
            )
        else:
            self.u_weight_params = None
        self.input_built = True

    def call(self, inputs):
        # Assigning variables from the number of inputs.
        instances = [self.compute_attention_scores(instance) for instance in inputs]
        # Stack instances into a single tensor.
        instances = ops.stack(instances)
        # Apply softmax over instances such that the output summation is equal to 1.
        alpha = ops.softmax(instances, axis=0)
        # Split to recreate the same array of tensors we had as inputs.
        return [alpha[i] for i in range(alpha.shape[0])]

    def compute_attention_scores(self, instance):
        # Reserve in-case "gated mechanism" used.
        original_instance = instance
        # tanh(v*h_k^T)
        instance = ops.tanh(ops.tensordot(instance, self.v_weight_params, axes=1))
        # for learning non-linear relations efficiently.
        if self.use_gated:
            instance = instance * ops.sigmoid(
                ops.tensordot(original_instance, self.u_weight_params, axes=1)
            )
        # w^T*(tanh(v*h_k^T)) / w^T*(tanh(v*h_k^T)*sigmoid(u*h_k^T))
        return ops.tensordot(instance, self.w_weight_params, axes=1)

# %% [markdown]
# ## Create the Attention-based Deep MIL Model

# %% [markdown]
# This section defines the architecture of the Attention-based Deep MIL model. The model first **applies data augmentation layers** to each input instance. Then, it **extracts features from each augmented instance using a pre-trained Xception model** (with frozen layers) followed by global average pooling and two dense layers. It then **applies the MILAttentionLayer** to calculate attention weights for each instance, allowing the model to **focus on the most relevant** ones. These attention weights are multiplied with the corresponding instance embeddings and concatenated to form a single representation for the entire bag. Finally, a classification layer is used to predict the bag's label based on this aggregated representation. This architecture enables the model to learn effectively from bags of instances by selectively attending to the most informative ones, leading to improved performance in MIL tasks.

# %%
def create_model(instance_shape, instances_count):
    # Extract features from inputs.
    inputs, embeddings = [], []
    extended_shape = (instance_shape[0], instance_shape[1], 3)
    base_model = Xception(
        weights="imagenet",
        include_top=False,
        input_shape=extended_shape,
    )
    # freeze all layers of Xception
    for layer in base_model.layers:
        layer.trainable = False
    dense_layer_1 = layers.Dense(64, activation="relu", kernel_regularizer=keras.regularizers.L2(0.01))
    dense_layer_2 = layers.Dense(64, activation="relu", kernel_regularizer=keras.regularizers.L2(0.01))
    # rand_rot = tf.keras.layers.RandomRotation(factor=2/36, fill_mode="constant", fill_value=0.0, seed=42)
    rand_flip = tf.keras.layers.RandomFlip("horizontal_and_vertical", seed=42)
    for _ in range(instances_count):
        inp = layers.Input(instance_shape)
        # Data Augmentation Layers
        # augmented_inp = rand_rot(inp)
        augmented_inp = rand_flip(inp)
        # convert to 3-channel input (for compatibility with Xception)
        inp_ext = layers.Lambda(lambda x: tf.concat([tf.expand_dims(x, axis=-1)] * 3, axis=-1))(augmented_inp)
        embed = base_model(inp_ext)
        pool = keras.layers.GlobalAveragePooling2D()(embed)
        dense_1 = dense_layer_1(pool)
        dense_2 = dense_layer_2(dense_1)
        inputs.append(inp)
        embeddings.append(dense_2)
    # Invoke the attention layer.
    alpha = MILAttentionLayer(
        weight_dim=256,
        kernel_reg=keras.regularizers.L2(0.01),
        use_gated=True,
        name="alpha",
    )(embeddings)
    # Multiply attention weights with the input layers.
    multiply_layers = [
        layers.multiply([alpha[i], embeddings[i]]) for i in range(len(alpha))
    ]
    # Concatenate layers.
    concat = layers.concatenate(multiply_layers, axis=1)
    # Classification output node.
    output = layers.Dense(2, activation="softmax")(concat)
    return keras.Model(inputs, output)

# %%
model = create_model(train_bags[0][0].shape, 3)  # use only 3 instances for visualisation purposes
keras.utils.plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# ## Compute Class Weights based on their frequency

# %% [markdown]
# This function is responsible for computing the class weights based on their count (frequency) in the given dataset. Using it during the model training, it will efficiently handle the slightly imbalanced dataset, as noted earlier.

# %%
def compute_class_weights(labels):
    # Count number of positive and negative bags.
    negative_count = len(np.where(labels == 0)[0])
    positive_count = len(np.where(labels == 1)[0])
    total_count = negative_count + positive_count
    # Build class weight dictionary.
    return {
        0: (1 / negative_count) * (total_count / 2),
        1: (1 / positive_count) * (total_count / 2),
    }

# %%
compute_class_weights(train_bags_labels)
# Out:
# {0: 1.3714285714285714, 1: 0.7868852459016393}

# %% [markdown]
# ## Build and Train the Attention-based Deep MIL Model

# %% [markdown]
# This section focuses on building and training the Attention-based Deep MIL model using the architecture defined in the previous section.
#
# During training, class weights are applied to address the slight class imbalance observed in the dataset. Model checkpoints, early stopping, and learning rate scheduling techniques are employed to facilitate efficient training and prevent overfitting.
#
# The plot_learning_curves function is used to visualize the training progress by plotting the training and validation loss/accuracy curves over epochs. This visualization aids in assessing model convergence, overfitting, and the overall performance of the model during training.
#
# Based on the generated learning curves, we can observe that the model generally converges well, showing decreasing loss and increasing accuracy on both the training and validation sets. This indicates that the model is learning effectively from the data. However, after approximately 10 epochs the gap between the train and validation curves is increasing, indicating that the model is starting to overfit. This is handled from the early stopping and checkpoint options that will select the model from epoch 17 as the top performaning candidate.

# %%
def plot_learning_curves(history, model_idx=0):
    """Plot training and validation loss/accuracy."""
    fig, axs = plt.subplots(1, 2, figsize=(12, 4))
    # Loss plot
    axs[0].plot(history.history["loss"], label="Train Loss")
    axs[0].plot(history.history["val_loss"], label="Val Loss")
    axs[0].set_title(f"Model {model_idx} - Loss")
    axs[0].set_xlabel("Epoch")
    axs[0].set_ylabel("Loss")
    axs[0].legend()
    axs[0].grid()
    # Accuracy plot
    axs[1].plot(history.history["accuracy"], label="Train Accuracy")
    axs[1].plot(history.history["val_accuracy"], label="Val Accuracy")
    axs[1].set_title(f"Model {model_idx} - Accuracy")
    axs[1].set_xlabel("Epoch")
    axs[1].set_ylabel("Accuracy")
    axs[1].legend()
    axs[1].grid()
    plt.show()

# %%
def train(train_data, train_labels, val_data, val_labels, model, model_idx=0):
    """Train a model with callbacks, better logging, and plots."""

    # Create a clean temp folder
    os.makedirs("/tmp", exist_ok=True)
    file_path = f"/tmp/best_model_{model_idx}.weights.h5"

    # Callbacks
    callbacks = [
        keras.callbacks.ModelCheckpoint(
            file_path,
            monitor="val_loss",
            verbose=1,
            mode="min",
            save_best_only=True,
            save_weights_only=True,
        ),
        keras.callbacks.EarlyStopping(
            monitor="val_loss",
            patience=10,
            restore_best_weights=True,
            verbose=1,
            mode="min",
        ),
        keras.callbacks.ReduceLROnPlateau(
            monitor="val_loss",
            factor=0.5,
            patience=3,
            verbose=1,
            mode="min",
            min_lr=1e-6,
        )
    ]
    # Compile model
    model.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"],
    )
    # Train model
    history = model.fit(
        train_data,
        train_labels,
        validation_data=(val_data, val_labels),
        epochs=80,
        class_weight=compute_class_weights(train_labels),
        batch_size=8,
        callbacks=callbacks,
        verbose=1,
    )
    # Load best weights
    model.load_weights(file_path)
    # Plot learning curves
    plot_learning_curves(history, model_idx=model_idx)
    return model

# %%
ENSEMBLE_COUNT = 1
instance_shape = train_bags[0][0].shape
models = [create_model(instance_shape, instances_count) for _ in range(ENSEMBLE_COUNT)]

trained_models = [
    train(train_bags, train_bags_labels, val_bags, val_bags_labels, model, idx)
    for idx, model in enumerate(tqdm(models))
]
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
#   0%|          | 0/1 [00:00<?, ?it/s]
# Epoch 1/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4416 - loss: 4.3558
# Epoch 1: val_loss improved from inf to 3.42245, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 399s 12s/step - accuracy: 0.4413 - loss: 4.3331 - val_accuracy: 0.3333 - val_loss: 3.4225 - learning_rate: 0.0010
# Epoch 2/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5099 - loss: 3.2102
# Epoch 2: val_loss improved from 3.42245 to 2.58509, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.5044 - loss: 3.1947 - val_accuracy: 0.5417 - val_loss: 2.5851 - learning_rate: 0.0010
# Epoch 3/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5384 - loss: 2.4381
# Epoch 3: val_loss improved from 2.58509 to 2.03968, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 92s 5s/step - accuracy: 0.5435 - loss: 2.4287 - val_accuracy: 0.7500 - val_loss: 2.0397 - learning_rate: 0.0010
# Epoch 4/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4950 - loss: 1.9412
# Epoch 4: val_loss improved from 2.03968 to 1.67687, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 71s 4s/step - accuracy: 0.5018 - loss: 1.9352 - val_accuracy: 0.8333 - val_loss: 1.6769 - learning_rate: 0.0010
# Epoch 5/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6532 - loss: 1.6240
# Epoch 5: val_loss improved from 1.67687 to 1.42387, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.6487 - loss: 1.6189 - val_accuracy: 0.7500 - val_loss: 1.4239 - learning_rate: 0.0010
# Epoch 6/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5274 - loss: 1.4067
# Epoch 6: val_loss improved from 1.42387 to 1.23179, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.5260 - loss: 1.4013 - val_accuracy: 0.7083 - val_loss: 1.2318 - learning_rate: 0.0010
# Epoch 7/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7112 - loss: 1.2218
# Epoch 7: val_loss improved from 1.23179 to 1.07727, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.7118 - loss: 1.2180 - val_accuracy: 0.7917 - val_loss: 1.0773 - learning_rate: 0.0010
# Epoch 8/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6984 - loss: 1.0724
# Epoch 8: val_loss improved from 1.07727 to 0.95507, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.7015 - loss: 1.0703 - val_accuracy: 0.8750 - val_loss: 0.9551 - learning_rate: 0.0010
# Epoch 9/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7381 - loss: 0.9629
# Epoch 9: val_loss improved from 0.95507 to 0.84711, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.7366 - loss: 0.9615 - val_accuracy: 0.8750 - val_loss: 0.8471 - learning_rate: 0.0010
# Epoch 10/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8068 - loss: 0.8608
# Epoch 10: val_loss improved from 0.84711 to 0.75011, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.8064 - loss: 0.8605 - val_accuracy: 0.8750 - val_loss: 0.7501 - learning_rate: 0.0010
# Epoch 11/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6284 - loss: 0.8039
# Epoch 11: val_loss improved from 0.75011 to 0.72177, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.6329 - loss: 0.8034 - val_accuracy: 0.7500 - val_loss: 0.7218 - learning_rate: 0.0010
# Epoch 12/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6124 - loss: 0.7710
# Epoch 12: val_loss improved from 0.72177 to 0.59319, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.6166 - loss: 0.7710 - val_accuracy: 0.8750 - val_loss: 0.5932 - learning_rate: 0.0010
# Epoch 13/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6315 - loss: 0.7863
# Epoch 13: val_loss improved from 0.59319 to 0.58384, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.6342 - loss: 0.7841 - val_accuracy: 0.7917 - val_loss: 0.5838 - learning_rate: 0.0010
# Epoch 14/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6733 - loss: 0.6832
# Epoch 14: val_loss did not improve from 0.58384
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.6688 - loss: 0.6867 - val_accuracy: 0.7500 - val_loss: 0.6901 - learning_rate: 0.0010
# Epoch 15/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5874 - loss: 0.7684
# Epoch 15: val_loss improved from 0.58384 to 0.56806, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.5911 - loss: 0.7652 - val_accuracy: 0.7500 - val_loss: 0.5681 - learning_rate: 0.0010
# Epoch 16/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5347 - loss: 0.8193
# Epoch 16: val_loss improved from 0.56806 to 0.56377, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.5377 - loss: 0.8150 - val_accuracy: 0.8750 - val_loss: 0.5638 - learning_rate: 0.0010
# Epoch 17/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7707 - loss: 0.6419
# Epoch 17: val_loss improved from 0.56377 to 0.50003, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.7700 - loss: 0.6403 - val_accuracy: 0.7917 - val_loss: 0.5000 - learning_rate: 0.0010
# Epoch 18/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6006 - loss: 0.7519
# Epoch 18: val_loss improved from 0.50003 to 0.48231, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.6041 - loss: 0.7465 - val_accuracy: 0.8750 - val_loss: 0.4823 - learning_rate: 0.0010
# Epoch 19/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7317 - loss: 0.6163
# Epoch 19: val_loss did not improve from 0.48231
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.7307 - loss: 0.6172 - val_accuracy: 0.8333 - val_loss: 0.5168 - learning_rate: 0.0010
# Epoch 20/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6159 - loss: 0.6841
# Epoch 20: val_loss did not improve from 0.48231
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.6198 - loss: 0.6840 - val_accuracy: 0.8333 - val_loss: 0.4972 - learning_rate: 0.0010
# Epoch 21/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6568 - loss: 0.6805
# Epoch 21: val_loss improved from 0.48231 to 0.46109, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.6560 - loss: 0.6806 - val_accuracy: 0.8750 - val_loss: 0.4611 - learning_rate: 0.0010
# Epoch 22/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7325 - loss: 0.6688
# Epoch 22: val_loss improved from 0.46109 to 0.45606, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.7339 - loss: 0.6646 - val_accuracy: 0.8750 - val_loss: 0.4561 - learning_rate: 0.0010
# Epoch 23/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.5602 - loss: 0.7092
# Epoch 23: val_loss improved from 0.45606 to 0.44191, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.5651 - loss: 0.7078 - val_accuracy: 0.8750 - val_loss: 0.4419 - learning_rate: 0.0010
# Epoch 24/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7693 - loss: 0.5480
# Epoch 24: val_loss did not improve from 0.44191
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.7670 - loss: 0.5495 - val_accuracy: 0.8750 - val_loss: 0.4487 - learning_rate: 0.0010
# Epoch 25/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8020 - loss: 0.5797
# Epoch 25: val_loss improved from 0.44191 to 0.42473, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.7972 - loss: 0.5832 - val_accuracy: 0.8750 - val_loss: 0.4247 - learning_rate: 0.0010
# Epoch 26/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8121 - loss: 0.5324
# Epoch 26: val_loss did not improve from 0.42473
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.8097 - loss: 0.5370 - val_accuracy: 0.7917 - val_loss: 0.5591 - learning_rate: 0.0010
# Epoch 27/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6505 - loss: 0.6767
# Epoch 27: val_loss did not improve from 0.42473
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.6549 - loss: 0.6713 - val_accuracy: 0.7917 - val_loss: 0.4765 - learning_rate: 0.0010
# Epoch 28/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8340 - loss: 0.5050
# Epoch 28: val_loss did not improve from 0.42473
#
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.8283 - loss: 0.5092 - val_accuracy: 0.7500 - val_loss: 0.5684 - learning_rate: 0.0010
# Epoch 29/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6496 - loss: 0.6354
# Epoch 29: val_loss did not improve from 0.42473
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.6565 - loss: 0.6299 - val_accuracy: 0.7917 - val_loss: 0.4386 - learning_rate: 5.0000e-04
# Epoch 30/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8107 - loss: 0.6041
# Epoch 30: val_loss improved from 0.42473 to 0.42006, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.8100 - loss: 0.6001 - val_accuracy: 0.8333 - val_loss: 0.4201 - learning_rate: 5.0000e-04
# Epoch 31/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8131 - loss: 0.5251
# Epoch 31: val_loss did not improve from 0.42006
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.8107 - loss: 0.5301 - val_accuracy: 0.8333 - val_loss: 0.4209 - learning_rate: 5.0000e-04
# Epoch 32/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7201 - loss: 0.5379
# Epoch 32: val_loss improved from 0.42006 to 0.41103, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.7216 - loss: 0.5402 - val_accuracy: 0.8750 - val_loss: 0.4110 - learning_rate: 5.0000e-04
# Epoch 33/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8574 - loss: 0.5006
# Epoch 33: val_loss did not improve from 0.41103
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.8547 - loss: 0.5059 - val_accuracy: 0.8750 - val_loss: 0.4352 - learning_rate: 5.0000e-04
# Epoch 34/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7830 - loss: 0.5403
# Epoch 34: val_loss improved from 0.41103 to 0.40575, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.7821 - loss: 0.5406 - val_accuracy: 0.8333 - val_loss: 0.4057 - learning_rate: 5.0000e-04
# Epoch 35/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6024 - loss: 0.7189
# Epoch 35: val_loss did not improve from 0.40575
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.6049 - loss: 0.7130 - val_accuracy: 0.8333 - val_loss: 0.4266 - learning_rate: 5.0000e-04
# Epoch 36/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7031 - loss: 0.6015
# Epoch 36: val_loss did not improve from 0.40575
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.7035 - loss: 0.6008 - val_accuracy: 0.7500 - val_loss: 0.4204 - learning_rate: 5.0000e-04
# Epoch 37/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6563 - loss: 0.6572
# Epoch 37: val_loss did not improve from 0.40575
#
# Epoch 37: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.6611 - loss: 0.6531 - val_accuracy: 0.8333 - val_loss: 0.4128 - learning_rate: 5.0000e-04
# Epoch 38/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7811 - loss: 0.5569
# Epoch 38: val_loss did not improve from 0.40575
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.7820 - loss: 0.5538 - val_accuracy: 0.8750 - val_loss: 0.4078 - learning_rate: 2.5000e-04
# Epoch 39/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8232 - loss: 0.5179
# Epoch 39: val_loss improved from 0.40575 to 0.40552, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.8192 - loss: 0.5200 - val_accuracy: 0.8333 - val_loss: 0.4055 - learning_rate: 2.5000e-04
# Epoch 40/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6963 - loss: 0.5910
# Epoch 40: val_loss improved from 0.40552 to 0.39772, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.6988 - loss: 0.5883 - val_accuracy: 0.8750 - val_loss: 0.3977 - learning_rate: 2.5000e-04
# Epoch 41/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7587 - loss: 0.5666
# Epoch 41: val_loss improved from 0.39772 to 0.39605, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.7540 - loss: 0.5677 - val_accuracy: 0.8750 - val_loss: 0.3961 - learning_rate: 2.5000e-04
# Epoch 42/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7831 - loss: 0.5116
# Epoch 42: val_loss did not improve from 0.39605
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.7838 - loss: 0.5100 - val_accuracy: 0.8333 - val_loss: 0.3964 - learning_rate: 2.5000e-04
# Epoch 43/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7559 - loss: 0.5238
# Epoch 43: val_loss did not improve from 0.39605
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.7547 - loss: 0.5254 - val_accuracy: 0.8333 - val_loss: 0.3962 - learning_rate: 2.5000e-04
# Epoch 44/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7201 - loss: 0.5627
# Epoch 44: val_loss did not improve from 0.39605
#
# Epoch 44: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.7184 - loss: 0.5652 - val_accuracy: 0.8333 - val_loss: 0.3970 - learning_rate: 2.5000e-04
# Epoch 45/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7878 - loss: 0.4630
# Epoch 45: val_loss improved from 0.39605 to 0.39212, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.7873 - loss: 0.4650 - val_accuracy: 0.8750 - val_loss: 0.3921 - learning_rate: 1.2500e-04
# Epoch 46/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7149 - loss: 0.6118
# Epoch 46: val_loss improved from 0.39212 to 0.39201, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.7160 - loss: 0.6109 - val_accuracy: 0.8750 - val_loss: 0.3920 - learning_rate: 1.2500e-04
# Epoch 47/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7617 - loss: 0.5644
# Epoch 47: val_loss did not improve from 0.39201
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.7592 - loss: 0.5641 - val_accuracy: 0.8333 - val_loss: 0.3982 - learning_rate: 1.2500e-04
# Epoch 48/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7860 - loss: 0.5482
# Epoch 48: val_loss did not improve from 0.39201
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.7848 - loss: 0.5472 - val_accuracy: 0.8333 - val_loss: 0.3935 - learning_rate: 1.2500e-04
# Epoch 49/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8434 - loss: 0.5011
# Epoch 49: val_loss improved from 0.39201 to 0.38957, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 51s 4s/step - accuracy: 0.8426 - loss: 0.5013 - val_accuracy: 0.8750 - val_loss: 0.3896 - learning_rate: 1.2500e-04
# Epoch 50/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7429 - loss: 0.5304
# Epoch 50: val_loss did not improve from 0.38957
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 81s 4s/step - accuracy: 0.7394 - loss: 0.5352 - val_accuracy: 0.8333 - val_loss: 0.3915 - learning_rate: 1.2500e-04
# Epoch 51/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7628 - loss: 0.5631
# Epoch 51: val_loss did not improve from 0.38957
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.7594 - loss: 0.5637 - val_accuracy: 0.8333 - val_loss: 0.3980 - learning_rate: 1.2500e-04
# Epoch 52/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7581 - loss: 0.5476
# Epoch 52: val_loss improved from 0.38957 to 0.38665, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.7607 - loss: 0.5465 - val_accuracy: 0.8750 - val_loss: 0.3867 - learning_rate: 1.2500e-04
# Epoch 53/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7614 - loss: 0.5607
# Epoch 53: val_loss improved from 0.38665 to 0.38564, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 84s 5s/step - accuracy: 0.7605 - loss: 0.5622 - val_accuracy: 0.8750 - val_loss: 0.3856 - learning_rate: 1.2500e-04
# Epoch 54/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7014 - loss: 0.5628
# Epoch 54: val_loss did not improve from 0.38564
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 79s 4s/step - accuracy: 0.7043 - loss: 0.5628 - val_accuracy: 0.8333 - val_loss: 0.3953 - learning_rate: 1.2500e-04
# Epoch 55/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7631 - loss: 0.5576
# Epoch 55: val_loss did not improve from 0.38564
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.7629 - loss: 0.5562 - val_accuracy: 0.8333 - val_loss: 0.3920 - learning_rate: 1.2500e-04
# Epoch 56/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8345 - loss: 0.5459
# Epoch 56: val_loss did not improve from 0.38564
#
# Epoch 56: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.8336 - loss: 0.5459 - val_accuracy: 0.8750 - val_loss: 0.3860 - learning_rate: 1.2500e-04
# Epoch 57/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7307 - loss: 0.5464
# Epoch 57: val_loss did not improve from 0.38564
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.7274 - loss: 0.5523 - val_accuracy: 0.8750 - val_loss: 0.3861 - learning_rate: 6.2500e-05
# Epoch 58/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7687 - loss: 0.5051
# Epoch 58: val_loss did not improve from 0.38564
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.7681 - loss: 0.5061 - val_accuracy: 0.8333 - val_loss: 0.3871 - learning_rate: 6.2500e-05
# Epoch 59/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8171 - loss: 0.4962
# Epoch 59: val_loss did not improve from 0.38564
#
# Epoch 59: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.8135 - loss: 0.4988 - val_accuracy: 0.8750 - val_loss: 0.3864 - learning_rate: 6.2500e-05
# Epoch 60/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7338 - loss: 0.5087
# Epoch 60: val_loss did not improve from 0.38564
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.7311 - loss: 0.5133 - val_accuracy: 0.8333 - val_loss: 0.3867 - learning_rate: 3.1250e-05
# Epoch 61/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8207 - loss: 0.4798
# Epoch 61: val_loss did not improve from 0.38564
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.8169 - loss: 0.4839 - val_accuracy: 0.8333 - val_loss: 0.3866 - learning_rate: 3.1250e-05
# Epoch 62/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7615 - loss: 0.5456
# Epoch 62: val_loss did not improve from 0.38564
#
# Epoch 62: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.7614 - loss: 0.5433 - val_accuracy: 0.8333 - val_loss: 0.3865 - learning_rate: 3.1250e-05
# Epoch 63/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7785 - loss: 0.5181
# Epoch 63: val_loss improved from 0.38564 to 0.38484, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 87s 5s/step - accuracy: 0.7795 - loss: 0.5190 - val_accuracy: 0.8750 - val_loss: 0.3848 - learning_rate: 1.5625e-05
# Epoch 64/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7704 - loss: 0.5527
# Epoch 64: val_loss improved from 0.38484 to 0.38461, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 54s 5s/step - accuracy: 0.7728 - loss: 0.5468 - val_accuracy: 0.8750 - val_loss: 0.3846 - learning_rate: 1.5625e-05
# Epoch 65/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7145 - loss: 0.5650
# Epoch 65: val_loss did not improve from 0.38461
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.7117 - loss: 0.5680 - val_accuracy: 0.8750 - val_loss: 0.3847 - learning_rate: 1.5625e-05
# Epoch 66/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7784 - loss: 0.4900
# Epoch 66: val_loss improved from 0.38461 to 0.38424, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 57s 5s/step - accuracy: 0.7762 - loss: 0.4923 - val_accuracy: 0.8750 - val_loss: 0.3842 - learning_rate: 1.5625e-05
# Epoch 67/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8202 - loss: 0.4697
# Epoch 67: val_loss did not improve from 0.38424
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.8196 - loss: 0.4725 - val_accuracy: 0.8750 - val_loss: 0.3842 - learning_rate: 1.5625e-05
# Epoch 68/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7492 - loss: 0.5593
# Epoch 68: val_loss did not improve from 0.38424
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.7476 - loss: 0.5592 - val_accuracy: 0.8750 - val_loss: 0.3844 - learning_rate: 1.5625e-05
# Epoch 69/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8031 - loss: 0.5156
# Epoch 69: val_loss improved from 0.38424 to 0.38384, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 91s 5s/step - accuracy: 0.8046 - loss: 0.5142 - val_accuracy: 0.8750 - val_loss: 0.3838 - learning_rate: 1.5625e-05
# Epoch 70/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8066 - loss: 0.5328
# Epoch 70: val_loss improved from 0.38384 to 0.38374, saving model to /tmp/best_model_0.weights.h5
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 85s 5s/step - accuracy: 0.8046 - loss: 0.5360 - val_accuracy: 0.8750 - val_loss: 0.3837 - learning_rate: 1.5625e-05
# Epoch 71/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7567 - loss: 0.5146
# Epoch 71: val_loss did not improve from 0.38374
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.7546 - loss: 0.5171 - val_accuracy: 0.8750 - val_loss: 0.3839 - learning_rate: 1.5625e-05
# Epoch 72/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6765 - loss: 0.6323
# Epoch 72: val_loss did not improve from 0.38374
#
# Epoch 72: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.6781 - loss: 0.6302 - val_accuracy: 0.8333 - val_loss: 0.3854 - learning_rate: 1.5625e-05
# Epoch 73/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7401 - loss: 0.5358
# Epoch 73: val_loss did not improve from 0.38374
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.7449 - loss: 0.5341 - val_accuracy: 0.8333 - val_loss: 0.3856 - learning_rate: 7.8125e-06
# Epoch 74/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8012 - loss: 0.5391
# Epoch 74: val_loss did not improve from 0.38374
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 83s 4s/step - accuracy: 0.8012 - loss: 0.5391 - val_accuracy: 0.8333 - val_loss: 0.3852 - learning_rate: 7.8125e-06
# Epoch 75/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6366 - loss: 0.6231
# Epoch 75: val_loss did not improve from 0.38374
#
# Epoch 75: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.6405 - loss: 0.6220 - val_accuracy: 0.8333 - val_loss: 0.3856 - learning_rate: 7.8125e-06
# Epoch 76/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.6704 - loss: 0.6284
# Epoch 76: val_loss did not improve from 0.38374
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.6709 - loss: 0.6298 - val_accuracy: 0.8333 - val_loss: 0.3856 - learning_rate: 3.9063e-06
# Epoch 77/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7714 - loss: 0.5356
# Epoch 77: val_loss did not improve from 0.38374
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.7673 - loss: 0.5368 - val_accuracy: 0.8333 - val_loss: 0.3856 - learning_rate: 3.9063e-06
# Epoch 78/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9027 - loss: 0.4637
# Epoch 78: val_loss did not improve from 0.38374
#
# Epoch 78: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.8998 - loss: 0.4660 - val_accuracy: 0.8333 - val_loss: 0.3853 - learning_rate: 3.9063e-06
# Epoch 79/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.7842 - loss: 0.5347
# Epoch 79: val_loss did not improve from 0.38374
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 50s 4s/step - accuracy: 0.7832 - loss: 0.5352 - val_accuracy: 0.8333 - val_loss: 0.3854 - learning_rate: 1.9531e-06
# Epoch 80/80
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.8443 - loss: 0.5156
# Epoch 80: val_loss did not improve from 0.38374
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 82s 4s/step - accuracy: 0.8434 - loss: 0.5156 - val_accuracy: 0.8333 - val_loss: 0.3852 - learning_rate: 1.9531e-06
# Epoch 80: early stopping
# Restoring model weights from the end of the best epoch: 70.
# 100%|██████████| 1/1 [1:35:31<00:00, 5731.95s/it]

# %% [markdown]
# ## Evaluate Trained Model

# %% [markdown]
# In this section the trained model is evaluated using various metrics in the test set. Based on the Confusion Matrix and the Classification Report, it is clear that the model is performing far above the random estimator for both positive and negative classses, with relatively low misclassifications.
# Furthermore, the Receiver Operating Characteristic (ROC) and the Precision-Recall curves, highlight the model's high discriminative power in successfully predicting the GDP low/high class of each bag, given the night-time images. Once again, with scores AUC=0.89 and AP=0.91 the model's performance is clearly superior than the chance level of a random estimator.

# %%
def predict(data, labels, model, batch_size=8):
    predictions = []
    attention_weights = []
    # Create intermediate model to get MIL attention layer weights.
    intermediate_model = keras.Model(model.input, model.get_layer("alpha").output)

    # Process data in batches
    for i in tqdm(range(0, len(data[0]), batch_size)):
        batch_data = [d[i:i+batch_size] for d in data]
        batch_predictions = model.predict(batch_data)
        predictions.append(batch_predictions)

        batch_attention_weights = intermediate_model.predict(batch_data)
        attention_weights.append(batch_attention_weights)

    class_predictions = np.concatenate(predictions, axis=0)
    attention_params = np.concatenate(attention_weights, axis=1)

    accuracy = accuracy_score(np.argmax(class_predictions, axis=1), labels)
    precision = precision_score(np.argmax(class_predictions, axis=1), labels)
    recall = recall_score(np.argmax(class_predictions, axis=1), labels)
    f1 = f1_score(np.argmax(class_predictions, axis=1), labels)

    print(f"Calculated Accuracy: {accuracy:.4f}")
    print(f"Calculated Precision: {precision:.4f}")
    print(f"Calculated Recall: {recall:.4f}")
    print(f"Calculated F1 Score: {f1:.4f}")

    # Remove the evaluate call from here

    return (
        class_predictions,
        attention_params,  # attention_params will not be returned here
        accuracy   # accuracy will not be returned here
    )

# %%
# Evaluate and predict classes and attention scores on validation data.
class_predictions, attention_params, accuracy = predict(test_bags, test_bags_labels, trained_models[0])
# Out:
#   0%|          | 0/9 [00:00<?, ?it/s]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#  11%|█         | 1/9 [00:03<00:30,  3.80s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#  22%|██▏       | 2/9 [00:09<00:33,  4.72s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#  33%|███▎      | 3/9 [00:14<00:30,  5.02s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#  44%|████▍     | 4/9 [00:18<00:22,  4.42s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#  56%|█████▌    | 5/9 [00:21<00:16,  4.12s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#  67%|██████▋   | 6/9 [00:25<00:11,  3.92s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#  78%|███████▊  | 7/9 [00:28<00:07,  3.78s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
#  89%|████████▉ | 8/9 [00:34<00:04,  4.29s/it]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 45s 45s/step
# 100%|██████████| 9/9 [01:56<00:00, 12.91s/it]

# %%
accuracy = accuracy_score(np.argmax(class_predictions, axis=1), test_bags_labels)
precision = precision_score(np.argmax(class_predictions, axis=1), test_bags_labels)
recall = recall_score(np.argmax(class_predictions, axis=1), test_bags_labels)
f1 = f1_score(np.argmax(class_predictions, axis=1), test_bags_labels)

print(f"Calculated Accuracy: {accuracy:.4f}")
print(f"Calculated Precision: {precision:.4f}")
print(f"Calculated Recall: {recall:.4f}")
print(f"Calculated F1 Score: {f1:.4f}")
# Out:
# Calculated Accuracy: 0.8143
# Calculated Precision: 0.7143
# Calculated Recall: 0.8929
# Calculated F1 Score: 0.7937

# %%
# print the classification report
print(classification_report(test_bags_labels, np.argmax(class_predictions, axis=1)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.91      0.83        35
#            1       0.89      0.71      0.79        35
#
#     accuracy                           0.81        70
#    macro avg       0.83      0.81      0.81        70
# weighted avg       0.83      0.81      0.81        70

# %%
cm = confusion_matrix(test_bags_labels, np.argmax(class_predictions, axis=1))
print(f"Confusion Matrix:\n{cm}")
# Out:
# Confusion Matrix:
# [[32  3]
#  [10 25]]

# %%
# Define the matrix as a dictionary
data = {"low": [0, 0.786], "high": [1.371, 0]}
index_labels = ["low", "high"]

# Create DataFrame
cm_df = pd.DataFrame(data, index=index_labels)

# Rename index name for row headers
cm_df.index.name = "Actual"
cm_df.columns.name = "Predicted"

# Display DataFrame
cm_df
# Out:
# Predicted    low   high
# Actual
# low        0.000  1.371
# high       0.786  0.000

# %%
cost_matrix = cm_df.to_numpy()
print(f"Cost Matrix: \n{cost_matrix}")
# Out:
# Cost Matrix:
# [[0.    1.371]
#  [0.786 0.   ]]

# %%
# find the total cost
total_cost = np.sum(cost_matrix * cm)
print(f"Total Cost: {total_cost}")
# Out:
# Total Cost: 11.972999999999999

# %%
# plot the ROC curve
fpr, tpr, thresholds = roc_curve(test_bags_labels, class_predictions[:, 1])
roc_auc = auc(fpr, tpr)
plt.figure()
plt.plot(fpr, tpr, color='orange', lw=2, label='ROC curve (AUC = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='blue', lw=2, linestyle='--', label='Chance Level')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")
plt.show()

# %%
# plot the Precision-Recall curve
precision, recall, thresholds = precision_recall_curve(test_bags_labels, class_predictions[:, 1])
pr_auc = auc(recall, precision)
plt.figure()
plt.plot(recall, precision, color='orange', lw=2, label='PR curve (AP = %0.2f)' % pr_auc)
plt.plot([0, 1], [0.5, 0.5], color='blue', lw=2, linestyle='--', label='Chance Level')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('Recall (Positive Label: 1)')
plt.ylabel('Precision (Positive Label: 1)')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# ## Explore Attention Weights

# %% [markdown]
# This is an example of the Attention Weights retrieved from the test set bags. It can be shown that all bags attention weights summation equals to 1.

# %%
attention_weights = np.squeeze(np.swapaxes(attention_params, 1, 0))
attention_weights.shape
# Out:
# (70, 40)

# %%
np.sum(attention_weights, axis=1)
# Out:
# array([1.        , 0.99999994, 1.0000001 , 1.0000001 , 0.9999998 ,
#        1.0000001 , 1.        , 0.9999999 , 1.        , 1.0000001 ,
#        1.        , 0.99999994, 1.0000001 , 0.9999997 , 1.        ,
#        1.0000001 , 0.99999994, 0.9999999 , 1.0000001 , 1.        ,
#        0.9999998 , 1.        , 0.9999999 , 0.9999998 , 1.        ,
#        0.9999998 , 1.        , 1.0000001 , 1.0000001 , 0.99999994,
#        0.9999999 , 1.        , 1.        , 0.99999994, 1.0000001 ,
#        0.9999999 , 0.99999994, 0.99999994, 1.        , 0.99999976,
#        1.        , 0.9999999 , 0.9999998 , 0.99999976, 0.99999994,
#        1.        , 1.        , 1.0000001 , 1.        , 0.9999999 ,
#        1.0000001 , 0.99999994, 1.        , 1.        , 1.0000001 ,
#        1.0000001 , 1.        , 0.99999994, 0.99999994, 1.0000002 ,
#        1.        , 0.99999994, 0.99999994, 1.        , 1.0000001 ,
#        0.99999994, 1.        , 1.0000001 , 1.0000001 , 0.99999994],
#       dtype=float32)

# %% [markdown]
# ## Plot Bag Images with Highest Softmax Scores

# %% [markdown]
# This section visualizes the model's predictions and attention weights by plotting the images within bags of the test set that received the highest scores in after the softmax layer.
#
# The plots focus on a selection of correctly classified bags, showcasing 3 bags classified as "positive" and 3 bags classified as "negative." This allows us to examine the instances that contributed most to the correct classification of these bags.
#
# For each selected bag, the top 10 images with the highest attention weights are displayed. This highlights the specific image instances that the model considered most important for its prediction. By focusing on the highest attention weights, we gain insights into the visual patterns or features that the model has learned to associate with each class.

# %%
def plot_results(data, labels, predictions, attention_weights):
    """Utility for plotting the top 10 images with highest attention weights
    for the 2 bags with the most certain predictions.

    Args:
      data: Input data that contains the bags of instances.
      labels: The associated bag labels of the input data.
      predictions: Class labels model predictions.
      attention_weights: Attention weights for each instance within the input data.
    """

    # Get prediction confidence for each bag
    confidence = np.max(predictions, axis=1)

    # Find indices of bags with highest confidence for each class
    positive_indices = np.where(predictions.argmax(1) == 1)[0]
    negative_indices = np.where(predictions.argmax(1) == 0)[0]

    top_pos = [-3, -2, -1]  # plot indicative examples of correct classification of positive class
    top_neg = [-3, -2, -1]  # plot indicative examples of correct classification of negative class
    top_positive_indices = positive_indices[np.argsort(confidence[positive_indices])[top_pos]]
    top_negative_indices = negative_indices[np.argsort(confidence[negative_indices])[top_neg]]

    # Plot the selected bags
    for bag_class, indices in [(1, top_positive_indices), (0, top_negative_indices)]:
        print(f"\n~~~~~~~~~~~~~~~~~ Class: {bag_class} ~~~~~~~~~~~~~~~~~\n")
        for i in indices:
            actual_label = labels[i][0]  # Get actual label from labels array
            print(f"Actual Label: {actual_label}, Predicted Label: {bag_class}, Softmax Score: {predictions[i]}")
            figure = plt.figure(figsize=(20, 10))
            num_imgs = 15
            # Get indices of top 10 images with highest attention weights
            top_10_indices = np.argsort(attention_weights[i])[-num_imgs-1:-1]
            # Plot the top 10 images
            for j, image_index in enumerate(top_10_indices):
                image = np.array(data)[image_index][i]
                figure.add_subplot(1, num_imgs, j + 1)
                plt.grid(False)
                plt.axis('off')
                plt.title(np.around(attention_weights[i][image_index], 2))
                plt.imshow(image, cmap='gray')
            plt.show()

plot_results(test_bags, test_bags_labels, class_predictions, attention_weights)
# Out:
# ~~~~~~~~~~~~~~~~~ Class: 1 ~~~~~~~~~~~~~~~~~
#
# Actual Label: 1, Predicted Label: 1, Softmax Score: [0.19802424 0.8019758 ]
# Actual Label: 1, Predicted Label: 1, Softmax Score: [0.13327849 0.86672145]
# Actual Label: 1, Predicted Label: 1, Softmax Score: [0.12204936 0.87795067]
# ~~~~~~~~~~~~~~~~~ Class: 0 ~~~~~~~~~~~~~~~~~
#
# Actual Label: 0, Predicted Label: 0, Softmax Score: [0.9573166  0.04268347]
# Actual Label: 0, Predicted Label: 0, Softmax Score: [0.95732516 0.04267484]
# Actual Label: 0, Predicted Label: 0, Softmax Score: [0.961701   0.03829899]

# %% [markdown]
# ## Statistical (Chi-Square) Test

# %% [markdown]
# The Chi-Square test can be used to compare the observed and expected class frequencies in the confusion matrix. This can help assess the goodness of fit of the classification model, indicating how well the model’s predictions align with the actual class distributions.
# The Chi-Square test answers the question "Is there a significant association between what the model predicts and what the true labels are, or could the observed results have occurred just by random guessing?". With a p-value < 0.05, the test proves that the the model predictions are statistically dependent on the actual labels, thus the trained model is not predicting at random.

# %%
# Perform the Chi-squared test
chi2, p, dof, expected = chi2_contingency(cm)

# Output the results
print(f"Chi-squared Statistic: {chi2:.4f}")
print(f"P-value: {p:.2e}")

# Optional interpretation
if p < 0.05:
    print("Result: Statistically significant association between actual and predicted labels (P-value < 0.05).")
else:
    print("Result: No statistically significant association between actual and predicted labels (P-value > 0.05).")
# Out:
# Chi-squared Statistic: 26.2500
# P-value: 3.00e-07
# Result: Statistically significant association between actual and predicted labels (P-value < 0.05).

# %% [markdown]
# The Chi-Square test performed on the model's confusion matrix computed earlier, yielded a statistic of 26.25 with 1 degree of freedom and a P-value of 3e-07. The P-value score which is lower than 0.05, indicates that there is a statistically significant association between the predicted and actual class labels, suggesting that the model's predictions are not due to random chance. This supports the conclusion that the classifier performs substantially better than a random estimator and captures relevant distinctions between the two classes of the given dataset.

# %% [markdown]
# ## Save best model & Test Set

# %% [markdown]
# This functionality is helpful for the reproducibility of the final results.

# %%
from google.colab import files
file_path = "/tmp/best_model_0.weights.h5"
files.download(file_path)

# %%
# download locally from colab the test_bags and test_bags_labels to be able to reload them
import pickle
with open('test_bags.pkl', 'wb') as f:
    pickle.dump(test_bags, f)
with open('test_bags_labels.pkl', 'wb') as f:
    pickle.dump(test_bags_labels, f)
# download locally from colab the test_bags and test_bags_labels to be able to reload them
from google.colab import files
# files.download('test_bags.pkl')
# files.download('test_bags_labels.pkl')

# %%
ENSEMBLE_COUNT = 1
instance_shape = train_bags[0][0].shape
trained_models = [create_model(instance_shape, instances_count) for _ in range(ENSEMBLE_COUNT)]
# Compile model
trained_models[0].compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-3),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"],
)
# load the best_model_0.weights.h5 from drive
trained_models[0].load_weights("/content/drive/MyDrive/VIIRS/CNN/best_model_0.weights.h5")
